# %% [markdown]
# # LiDAR

# %%
from pathlib import Path
from geoid_correction import (compute_geoid_height_raster, apply_geoid_from_orthometric_dem) 

dem_path = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/LiDARHD_ref/03_final_DSM_50m/DSM_MNS_LiDARHD_50m_AOI_MASKED_EPSG4326.tif"
raf_path = "RAF20.tac"
output_dir = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/LiDARHD_ref/Ellps"

# 1. Compute geoid height
geoid_path = f"{output_dir}/geoid_height_EPSG4326.tif"
compute_geoid_height_raster(dem_path, raf_path, geoid_path)

# 3. OR recover ellipsoidal DEM from orthometric DEM
recovered_ellipsoidal = f"{output_dir}/DSM_LiDARHD_50m_EPSG4326_Ellps.tif"
apply_geoid_from_orthometric_dem(dem_path, geoid_path, recovered_ellipsoidal)
# Out:
#  Step 1: Loading DEM...
# ✅ DEM loaded
#  Step 2: Reading RAF20 geoid file...
#  RAF20 geoid loaded
#  Step 3: Reprojecting DEM coordinates to EPSG:4326...
#  Reprojection complete
#  Step 4: Interpolating geoid values...
#  Interpolation complete
#  Step 5: Writing geoid height raster...
#  Geoid height raster saved to: /mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/LiDARHD_ref/Ellps/geoid_height_EPSG4326.tif
#  Total runtime: 0.18 seconds
#  Convert orthometric DEM to ellipsoidal DEM (valid pixels only)...
#  Orthometric DEM saved to: /mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/LiDARHD_ref/Ellps/DSM_LiDARHD_50m_EPSG4326_Ellps.tif
# '/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/LiDARHD_ref/Ellps/DSM_LiDARHD_50m_EPSG4326_Ellps.tif'

# %%
from geoid_correction import plot_geoid_raster  

# Path to your geoid raster
geoid_path = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/LiDARHD_ref/Ellps/geoid_height_EPSG4326.tif"

# Call the plot function
plot_geoid_raster(geoid_path, title="La Berarde Geoid Height (m)")
# Out:
# 🔹 Plotting geoid raster with contours...
# ✅ Geoid raster with contours plotted.

# %% [markdown]
# # Copernicus DEM

# %%
from pathlib import Path
from geoid_correction import (compute_geoid_height_raster, apply_geoid_from_orthometric_dem) 

dem_path = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/Copernicus_ref/Copernicus_GLO30_30m.tif"
raf_path = "RAF20.tac"
output_dir = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/Copernicus_ref/Ellps"

# 1. Compute geoid height
geoid_path = f"{output_dir}/geoid_height_EPSG4326.tif"
compute_geoid_height_raster(dem_path, raf_path, geoid_path)

# 3. OR recover ellipsoidal DEM from orthometric DEM
recovered_ellipsoidal = f"{output_dir}/DSM_Cop_30m_EPSG4326_Ellps.tif"
apply_geoid_from_orthometric_dem(dem_path, geoid_path, recovered_ellipsoidal)
# Out:
#  Step 1: Loading DEM...
# ✅ DEM loaded
#  Step 2: Reading RAF20 geoid file...
#  RAF20 geoid loaded
#  Step 3: Reprojecting DEM coordinates to EPSG:4326...
#  Reprojection complete
#  Step 4: Interpolating geoid values...
#  Interpolation complete
#  Step 5: Writing geoid height raster...
#  Geoid height raster saved to: /mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/Copernicus_ref/Ellps/geoid_height_EPSG4326.tif
#  Total runtime: 2.32 seconds
#  Convert orthometric DEM to ellipsoidal DEM (valid pixels only)...
#  Orthometric DEM saved to: /mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/Copernicus_ref/Ellps/DSM_Cop_30m_EPSG4326_Ellps.tif
# '/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/Copernicus_ref/Ellps/DSM_Cop_30m_EPSG4326_Ellps.tif'

# %% [markdown]
# # SRTM DEM

# %%
from pathlib import Path
from geoid_correction import (compute_geoid_height_raster, apply_geoid_from_orthometric_dem) 

dem_path = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/SRTM_ref/SRTM1_30m.tif"
raf_path = "RAF20.tac"
output_dir = "/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/SRTM_ref/Ellps"

# 1. Compute geoid height
geoid_path = f"{output_dir}/geoid_height_EPSG4326.tif"
compute_geoid_height_raster(dem_path, raf_path, geoid_path)

# 3. OR recover ellipsoidal DEM from orthometric DEM
recovered_ellipsoidal = f"{output_dir}/DSM_SRTM_30m_EPSG4326_Ellps.tif"
apply_geoid_from_orthometric_dem(dem_path, geoid_path, recovered_ellipsoidal)
# Out:
#  Step 1: Loading DEM...
# ✅ DEM loaded
#  Step 2: Reading RAF20 geoid file...
#  RAF20 geoid loaded
#  Step 3: Reprojecting DEM coordinates to EPSG:4326...
#  Reprojection complete
#  Step 4: Interpolating geoid values...
#  Interpolation complete
#  Step 5: Writing geoid height raster...
#  Geoid height raster saved to: /mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/SRTM_ref/Ellps/geoid_height_EPSG4326.tif
#  Total runtime: 0.78 seconds
#  Convert orthometric DEM to ellipsoidal DEM (valid pixels only)...
#  Orthometric DEM saved to: /mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/SRTM_ref/Ellps/DSM_SRTM_30m_EPSG4326_Ellps.tif
# '/mnt/summer/USERS/KOAI/Cosmo-SkyMed/Rererence_DEM/SRTM_ref/Ellps/DSM_SRTM_30m_EPSG4326_Ellps.tif'
